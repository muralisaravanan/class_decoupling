# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from classy import Class
import math
import cycler

# %%
T_CMB=2.725

# %%
mod0 = np.loadtxt("freestreaming_Nddec0cl_lensed.dat")
mod1 = np.loadtxt("freestreaming_Nddec1cl_lensed.dat")
mod2 = np.loadtxt("freestreaming_Nddec_2cl_lensed.dat")
mod3 = np.loadtxt("zdec1e4_Nddec1cl_lensed.dat")
mod4 = np.loadtxt("zdec1e4_Nddec2cl_lensed.dat")
mod5 = np.loadtxt("zdec1e3_Nddec1cl_lensed.dat")
mod6 = np.loadtxt("zdec1e3_Nddec2cl_lensed.dat")

models = [mod0,mod1, mod2, mod3, mod4, mod5, mod6]

ll_values = []
tt_values = []
ee_values = []
labels = ["freestreaming no decoup", "free_streaming ddec 1", "freestreaming ddec 2", "zdec = 1e4, N=1", "zdec = 1e4, N=2",
         "zdec = 1e3, N=1", "zdec = 1e3, N=2"]

#norm = models.get(0).lensed_cl(2500)['tt'][400]
for  model in models:
    ll = model[:,0]
    cl_tt = model[:,1]
    cl_ee = model[:,2]
    ll_values.append(ll)
    tt_values.append(cl_tt)
    ee_values.append(cl_ee)

# %%
plt.rc('lines', linewidth=1)
#plt.rc('axes', prop_cycle=(cycler.cycler('color', ['r', 'g', 'b', 'y']) + cycler.cycler('linestyle', ['-', '--', ':', '-.'])))

color = plt.cm.rainbow(np.flip(np.linspace(0, 1, len(ll_values))))
plt.rcParams["figure.figsize"] = (5,2.75)
plt.rcParams['figure.dpi'] = 300


for i in range(len(ll_values[:3])):

    #plt.xlim(500,2500)
    ll = ll_values[i]
    cl_tt = tt_values[i]
    
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(100,2500)
    plt.ylim(1e-6,1e-4)
    plt.xlabel('$\ell$', fontsize=10)
    plt.ylabel('$\ell (\ell+1)/2\pi * C_\ell^\mathrm{TT}  [ 10^2 mK^2] $')#, fontsize=20)
    #plt.title("TT Power specturum with varying $N_{\mathrm{fluid}}$ and $N_{\mathrm{total}} = 3.044$)")#, fontsize=20)
    plt.plot(ll,cl_tt*T_CMB**2*(10**6)/(100), label = labels[i], c = color[i])
    plt.legend(loc=1, prop={'size': 4})
    #plt.xticks(np.arange(500, 2600,500))
    #plt.yticks(np.arange(6,19,4))

# %%
for i in [3,4]:

    #plt.xlim(500,2500)
    ll = ll_values[i]
    cl_tt = tt_values[i]
    
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(100,2500)
    plt.ylim(1e-6,1e-4)
    plt.xlabel('$\ell$', fontsize=10)
    plt.ylabel('$\ell (\ell+1)/2\pi * C_\ell^\mathrm{TT}  [ 10^2 mK^2] $')#, fontsize=20)
    #plt.title("TT Power specturum with varying $N_{\mathrm{fluid}}$ and $N_{\mathrm{total}} = 3.044$)")#, fontsize=20)
    plt.plot(ll,cl_tt*T_CMB**2*(10**6)/(100), label = labels[i], c = color[i])
    plt.legend(loc=1, prop={'size': 4})
    #plt.xticks(np.arange(500, 2600,500))
    #plt.yticks(np.arange(6,19,4))

# %%
for i in [5,6]:

    #plt.xlim(500,2500)
    ll = ll_values[i]
    cl_tt = tt_values[i]
    
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(100,2500)
    plt.ylim(1e-6,1e-4)
    plt.xlabel('$\ell$', fontsize=10)
    plt.ylabel('$\ell (\ell+1)/2\pi * C_\ell^\mathrm{TT}  [ 10^2 mK^2] $')#, fontsize=20)
    #plt.title("TT Power specturum with varying $N_{\mathrm{fluid}}$ and $N_{\mathrm{total}} = 3.044$)")#, fontsize=20)
    plt.plot(ll,cl_tt*T_CMB**2*(10**6)/(100), label = labels[i], c = color[i])
    plt.legend(loc=1, prop={'size': 4})
    #plt.xticks(np.arange(500, 2600,500))
    #plt.yticks(np.arange(6,19,4))

# %%
for i in [1,3]:

    #plt.xlim(500,2500)
    ll = ll_values[i]
    cl_tt = tt_values[i]
    
    plt.xscale('log')
    plt.yscale('linear')
    plt.xlim(100,2500)
    plt.ylim(1e-6,1e-4)
    plt.xlabel('$\ell$', fontsize=10)
    plt.ylabel('$\ell (\ell+1)/2\pi * C_\ell^\mathrm{TT}  [ 10^2 mK^2] $')#, fontsize=20)
    #plt.title("TT Power specturum with varying $N_{\mathrm{fluid}}$ and $N_{\mathrm{total}} = 3.044$)")#, fontsize=20)
    plt.plot(ll,cl_tt*T_CMB**2*(10**6)/(100), label = labels[i], c = color[i])
    plt.legend(loc=1, prop={'size': 4})
    #plt.xticks(np.arange(500, 2600,500))
    #plt.yticks(np.arange(6,19,4))

# %%
def test_Pk(models, mod1_index, mod2_index):
    model1_Pk = {'tt': tt_values[mod1_index], 'ee':ee_values[mod1_index]}
    model2_Pk = {'tt': tt_values[mod2_index], 'ee':ee_values[mod2_index]}
    T_CMB = 2.725
    for mode in ['tt','ee']:
        if np.array_equal(model1_Pk[mode], model2_Pk[mode]):
            print(mode)
            print(str(labels[mod1_index]) + " and " + str(labels[mod2_index]) + " are equivalent")
            
        else:
            
            ll = ll_values[0]
            values1 = model1_Pk[mode]*T_CMB**2*(ll)*(ll+1)*(10**12)/(2.*math.pi)
            values2 = model2_Pk[mode]*T_CMB**2*(ll)*(ll+1)*(10**12)/(2.*math.pi)
            difference = (values2-values1)/values1
            plt.figure()
            plt.xscale('linear')
            plt.yscale('linear')
            plt.xlabel('$\ell$', fontsize=10)
            plt.ylabel('$\Delta D_\ell^\mathrm{' +str(mode) + '} [ \mu K^2] $')#, fontsize=20)
            plt.title("Power specturum difference " +str(labels[mod1_index]) + " and " + str(labels[mod2_index]))#, fontsize=20)
            plt.plot(ll,difference, linestyle='--')
            plt.figure()
            plt.xlabel('$\ell$', fontsize=10)
            plt.ylabel('$\ell (\ell+1)/2\pi * C_\ell^\mathrm{TT}  [ 10^2 mK^2] $')#, fontsize=20)
            plt.title("TT Power specturum with" +str(labels[mod1_index]) + " and " + str(labels[mod2_index]))#, fontsize=20)
            plt.plot(ll,values1*T_CMB**2*(10**6)/(100), label = labels[i], c = color[i])
            plt.plot(ll,values2*T_CMB**2*(10**6)/(100), label = labels[i], c = color[i])
            plt.legend(loc=1, prop={'size': 4})

# %%
test_Pk(models,2,4)

# %%
test_Pk(models,1,3)

# %%
test_Pk(models,0,1)

# %%
test_Pk(models, 0,2)

# %%
test_Pk(models, 1,2)
